# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaish2025/ML/blob/main/RE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Path and version numbers for python depend on operating system
# !which python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.10.12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# environment variable
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# install virtual environment package
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 27.7 MB/s eta 0:00:00
# ...

# %%
# create virtual environment
# !virtualenv myenv
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 1225ms
#   creator CPython3Posix(dest=/content/myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==24.3.1, setuptools==75.6.0, wheel==0.45.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2025-01-10 05:48:26--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 147784736 (141M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 140.94M   147MB/s    in 1.0s
#
# 2025-01-10 05:48:27 (147 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [147784736/147784736]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.

# %%
import os

# %%
# !conda create -q -y --prefix /usr/local/envs/myenv python=3.7
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.12.31 |       h06a4308_0         128 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-22.3.1                 |   py37h06a4308_0         2.7 MB
#     python-3.7.16              |       h7a1cb2a_0        44.8 MB
#     setuptools-65.6.3          |   py37h06a4308_0         1.1 MB
#     wheel-0.38.4               |   py37h06a4308_0          63 KB
#     ------------------------------------------------------------
#                                            Total:        52.7 MB
#
# ...

# %%
# !git clone https://github.com/zjunlp/HVPNeT
# Out:
# Cloning into 'HVPNeT'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 103 (delta 29), reused 24 (delta 24), pack-reused 68 (from 1)
# Receiving objects: 100% (103/103), 1.93 MiB | 10.92 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
os.environ['CONDA_PREFIX'] = '/usr/local/envs/myenv'
os.environ['PATH'] = '/usr/local/envs/myenv/bin:' + os.environ['PATH']

# %%
# !pip install torch==1.7.1 torchvision==0.8.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 40.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 44.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 83.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Change the requirements.txt after GitClone to the below and then continue running the cells below
#
# transformers==4.11.3
# tensorboardX==2.4
# TorchCRF==1.1.0
# wandb==0.12.1
# scikit-learn==1.0
# seqeval==1.2.2

# %%
# !pip install -r /content/HVPNeT/requirements.txt

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement pytorch==1.7.0 (from versions: 0.1.2, 1.0.2)
# ERROR: No matching distribution found for pytorch==1.7.0

# %%
# !python --version  # Should show Python 3.7
# Out:
# Python 3.7.16

# %% [markdown]
# The below pip uninstall cell needs to be execured incase colab says "the session runtime needs to be restarted" ONLY

# %%
# !pip uninstall torch torchvision Pillow -y
# Out:
# Found existing installation: torch 1.7.1
# Uninstalling torch-1.7.1:
#   Successfully uninstalled torch-1.7.1
# Found existing installation: torchvision 0.8.2
# Uninstalling torchvision-0.8.2:
#   Successfully uninstalled torchvision-0.8.2
# Found existing installation: Pillow 9.5.0
# Uninstalling Pillow-9.5.0:
#   Successfully uninstalled Pillow-9.5.0

# %%
# !pip install pytorch-crf==0.7.2

# %%
# !python --version  # Should show Python 3.7
# !python -c "import torch; print(torch.__version__)"  # Should show PyTorch 1.0.0
# !pip show pytorch-crf  # Should show version 0.7.2
# Out:
# Python 3.7.16
# 1.13.1+cu117
# Name: pytorch-crf
# Version: 0.7.2
# Summary: Conditional random field in PyTorch
# Home-page: https://github.com/kmkurn/pytorch-crf
# Author: Kemal Kurniawan
# Author-email: kemal@kkurniawan.com
# License: MIT
# Location: /usr/local/envs/myenv/lib/python3.7/site-packages
# Requires:
# Required-by:

# %% [markdown]
# Create a folder in HVPNeT named data, create 2 foldeer NER_data,RE_data in it.

# %%
import shutil

# Source and destination paths
source_folder = '/content/drive/MyDrive/Review2/FYP_Review2/RpBERT/RE/twitter2015/twitter15_data/twitter2015'
destination_folder = '/content/HVPNeT/data/NER_data/twitter2015'

# Copying the folder
shutil.copytree(source_folder, destination_folder, dirs_exist_ok=True)

print(f"Folder copied from {source_folder} to {destination_folder}")
# Out:
# Folder copied from /content/drive/MyDrive/Review2/FYP_Review2/RpBERT/RE/twitter2015/twitter15_data/twitter2015 to /content/HVPNeT/data/NER_data/twitter2015

# %%
import shutil

# Source and destination paths
source_folder = '/content/drive/MyDrive/Review2/FYP_Review2/RpBERT/RE/twitter2015/twitter15_data/twitter2015_images'
destination_folder = '/content/HVPNeT/data/NER_data/twitter2015_images'

# Copying the folder
shutil.copytree(source_folder, destination_folder, dirs_exist_ok=True)

print(f"Folder copied from {source_folder} to {destination_folder}")
# Out:
# Folder copied from /content/drive/MyDrive/Review2/FYP_Review2/RpBERT/RE/twitter2015/twitter15_data/twitter2015_images to /content/HVPNeT/data/NER_data/twitter2015_images

# %% [markdown]
# **The below 3 cells are to create the folders in Drive for the first time. So, these can be ignored as the foders are already there**

# %%
# Change to the correct directory
# %cd /content/drive/MyDrive/Review2/FYP_Review2/RpBERT/RE

# Create the folder 'twitter2015' inside the RE folder
# !mkdir -p twitter2017

# Extract the tar.gz file to the twitter2015 folder
# !tar -xzvf /content/drive/MyDrive/Review2/FYP_Review2/RpBERT/resources/datasets/twitter17_data.tar.gz -C twitter2017

# List the contents of twitter2015 folder to confirm extraction
# !ls twitter2017
# Out:
# Streaming output truncated to the last 5000 lines.
# data/twitter17_detect/crops/16_05_01_400_crop_0.jpg
# data/twitter17_detect/crops/16_05_22_709_crop_1.jpg
# data/twitter17_detect/crops/17_06_5878_crop_0.jpg
# data/twitter17_detect/crops/O_2532_crop_2.jpg
# data/twitter17_detect/crops/O_4563_crop_0.jpg
# data/twitter17_detect/crops/O_1987_crop_0.jpg
# data/twitter17_detect/crops/O_3641_crop_1.jpg
# data/twitter17_detect/crops/17_06_11727_crop_2.jpg
# data/twitter17_detect/crops/O_3749_crop_1.jpg
# data/twitter17_detect/crops/16_05_30_656_crop_2.jpg
# data/twitter17_detect/crops/16_05_01_208_crop_1.jpg
# data/twitter17_detect/crops/16_05_09_716_crop_1.jpg
# data/twitter17_detect/crops/16_05_05_612_crop_1.jpg
# data/twitter17_detect/crops/17_06_11210_crop_1.jpg
# data/twitter17_detect/crops/O_4123_crop_0.jpg
# data/twitter17_detect/crops/16_05_31_831_crop_1.jpg
# data/twitter17_detect/crops/O_4737_crop_1.jpg
# data/twitter17_detect/crops/17_06_1_crop_0.jpg
# ...

# %%
# Change to the correct directory
# %cd /content/drive/MyDrive/Review2/FYP_Review2/RpBERT/RE

# Create the folder 'twitter2015' inside the RE folder
# !mkdir -p twitter2015

# Extract the tar.gz file to the twitter2015 folder
# !tar -xzvf /content/drive/MyDrive/Review2/FYP_Review2/RpBERT/resources/datasets/twitter15_data.tar.gz -C twitter2015

# List the contents of twitter2015 folder to confirm extraction
# !ls twitter2015
# Out:
# Streaming output truncated to the last 5000 lines.
# twitter15_data/twitter2015_aux_images/test/crops/3234_pred_yolo_crop_6242.png
# twitter15_data/twitter2015_aux_images/test/crops/._1448_pred_yolo_crop_2831.png
# twitter15_data/twitter2015_aux_images/test/crops/1448_pred_yolo_crop_2831.png
# twitter15_data/twitter2015_aux_images/test/crops/._931_pred_yolo_crop_1781.png
# twitter15_data/twitter2015_aux_images/test/crops/931_pred_yolo_crop_1781.png
# twitter15_data/twitter2015_aux_images/test/crops/._3146_pred_yolo_crop_6074.png
# twitter15_data/twitter2015_aux_images/test/crops/3146_pred_yolo_crop_6074.png
# twitter15_data/twitter2015_aux_images/test/crops/._2979_pred_yolo_crop_5749.png
# twitter15_data/twitter2015_aux_images/test/crops/2979_pred_yolo_crop_5749.png
# twitter15_data/twitter2015_aux_images/test/crops/._3217_pred_yolo_crop_6207.png
# twitter15_data/twitter2015_aux_images/test/crops/3217_pred_yolo_crop_6207.png
# ...

# %%
# Change to the correct directory
# %cd /content/drive/MyDrive/Review2/FYP_Review2/RpBERT/RE/MNRE

# Download the data into the MNRE directory
# !wget http://120.27.214.45/Data/re/multimodal/data.tar.gz

# Extract the tar.gz file into the current directory
# !tar -xzvf data.tar.gz

# Rename or move the extracted folder to RE_data inside MNRE
# !mv data RE_data

# Confirm the change by listing the contents of the MNRE folder
# !ls RE_data
# Out:
# Streaming output truncated to the last 5000 lines.
# data/img_vg/train/crops/3099_pred_yolo_crop_189.png
# data/img_vg/train/crops/7698_pred_yolo_crop_9283.png
# data/img_vg/train/crops/6169_pred_yolo_crop_26734.png
# data/img_vg/train/crops/6146_pred_yolo_crop_11545.png
# data/img_vg/train/crops/7701_pred_yolo_crop_12883.png
# data/img_vg/train/crops/9644_pred_yolo_crop_4235.png
# data/img_vg/train/crops/7516_pred_yolo_crop_1971.png
# data/img_vg/train/crops/10548_pred_yolo_crop_14424.png
# data/img_vg/train/crops/252_pred_yolo_crop_32523.png
# data/img_vg/train/crops/5983_pred_yolo_crop_14244.png
# data/img_vg/train/crops/10401_pred_yolo_crop_10399.png
# data/img_vg/train/crops/2069_pred_yolo_crop_17712.png
# data/img_vg/train/crops/6404_pred_yolo_crop_16904.png
# data/img_vg/train/crops/739_pred_yolo_crop_10264.png
# data/img_vg/train/crops/5058_pred_yolo_crop_5055.png
# data/img_vg/train/crops/9565_pred_yolo_crop_28986.png
# data/img_vg/train/crops/4629_pred_yolo_crop_3500.png
# ...
